# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/Clasificaciones_LaLiga.csv", delimiter=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Temporada     520 non-null    object
#  1   Posicion J38  500 non-null    float64
#  2   Equipo        500 non-null    object
#  3   Puntos J38    500 non-null    float64
#  4   PJ Total      500 non-null    float64
#  5   G Total       500 non-null    float64
#  6   E Total       500 non-null    float64
#  7   PTotal        500 non-null    float64
#  8   GF Total      500 non-null    float64
#  9   GC Total      500 non-null    float64
#  10  Dif Total     500 non-null    object
#  11  Posicion J29  520 non-null    int64
#  12  Equipo J29    520 non-null    object
#  13  Puntos J29    520 non-null    int64
#  14  PJ 29         520 non-null    int64
#  15  G 29          520 non-null    int64
#  16  E 29          520 non-null    int64
#  17  P 29          520 non-null    int64
# ...

# %%
print(datos.columns)
# Out:
# Index(['Temporada,Posicion J38,Equipo,Puntos J38,PJ Total,G Total,E Total,PTotal,GF Total,GC Total,Dif Total,Posicion J29,Equipo J29,Puntos J29,PJ 29,G 29,E 29,P 29,GF 29,GC 29,Dif 29'], dtype='object')

# %%
df.head()
# Out:
#   Temporada  Posicion J38             Equipo  Puntos J38  PJ Total  G Total  \
# 0     98-99           1.0          Barcelona        74.0      38.0     23.0
# 1     98-99           2.0      Athletic Club        65.0      38.0     17.0
# 2     98-99           3.0      Real Sociedad        63.0      38.0     16.0
# 3     98-99           4.0  Real Madrid C. F.        63.0      38.0     17.0
# 4     98-99           5.0  R. C. D. Mallorca        60.0      38.0     16.0
#
#    E Total  PTotal  GF Total  GC Total  ... Posicion J29           Equipo J29  \
# 0      5.0    10.0      78.0      56.0  ...            1            Barcelona
# 1     14.0     7.0      52.0      42.0  ...            2  R. C. Celta de Vigo
# 2     15.0     7.0      60.0      37.0  ...            3       Valencia C. F.
# 3     12.0     9.0      63.0      45.0  ...            4    R. C. D. Mallorca
# 4     12.0    10.0      55.0      39.0  ...            5    Real Madrid C. F.
#
# ...

# %%
df.describe()
# Out:
#        Posicion J38  Puntos J38  PJ Total     G Total     E Total      PTotal  \
# count    500.000000  500.000000     500.0  500.000000  500.000000  500.000000
# mean      10.500000   52.162000      38.0   14.170000    9.660000   14.170000
# std        5.772056   15.392518       0.0    5.511611    2.872089    4.860076
# min        1.000000   13.000000      38.0    2.000000    1.000000    1.000000
# 25%        5.750000   42.000000      38.0   10.000000    8.000000   11.000000
# 50%       10.500000   49.000000      38.0   13.000000   10.000000   15.000000
# 75%       15.250000   60.000000      38.0   17.000000   12.000000   17.000000
# max       20.000000  100.000000      38.0   32.000000   18.000000   29.000000
#
#          GF Total    GC Total  Posicion J29  Puntos J29       PJ 29  \
# count  500.000000  500.000000    520.000000  520.000000  520.000000
# mean    50.630000   50.610000     10.500000   39.748077   28.996154
# ...

# %%
plt.hist(df["Puntos J38"])
plt.xlabel("Puntos en la jornada 38")
plt.ylabel("Frecuencia")
plt.title("Distirbucion de puntos en la jornada 38")
plt.show()

# %%
sns.scatterplot(x= "G Total", y= "Puntos J38", data = df)
plt.xlabel("Total de partidos ganados")
plt.ylabel("Puntos en la jornada 38")
plt.title("Relacion entre partidos ganados y puntos en la jornada 38")
plt.show()

# %%
df_1 = df.copy()
df_1 = df_1.dropna()

# %%
df['Dif Total'] = pd.to_numeric(df['Dif Total'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Temporada     520 non-null    object
#  1   Posicion J38  500 non-null    float64
#  2   Equipo        500 non-null    object
#  3   Puntos J38    500 non-null    float64
#  4   PJ Total      500 non-null    float64
#  5   G Total       500 non-null    float64
#  6   E Total       500 non-null    float64
#  7   PTotal        500 non-null    float64
#  8   GF Total      500 non-null    float64
#  9   GC Total      500 non-null    float64
#  10  Dif Total     203 non-null    float64
#  11  Posicion J29  520 non-null    int64
#  12  Equipo J29    520 non-null    object
#  13  Puntos J29    520 non-null    int64
#  14  PJ 29         520 non-null    int64
#  15  G 29          520 non-null    int64
#  16  E 29          520 non-null    int64
#  17  P 29          520 non-null    int64
# ...

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True, cmap= "coolwarm")
plt.title("Mapa de color de correlaciones entre caracteristicas")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 correlation_matrix = df.corr()
#       2 sns.heatmap(correlation_matrix, annot = True, cmap= "coolwarm")
#       3 plt.title("Mapa de color de correlaciones entre caracteristicas")
#
# File c:\Users\Adri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Adri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...
